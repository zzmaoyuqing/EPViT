# %% [markdown]
# ### conda environment：pytorchpy3.8
# ### focal loss VS cross entropy loss

# %%
import pandas as pd

# %% [markdown]
# # input

# %%
xlsx_file = pd.ExcelFile('different_lossfunction_result.xlsx')

# %%
df_5093 = pd.read_excel(xlsx_file,'PPI5093',index_col=0)
df_5093
# Out:
#                    Accuracy  Precision  Recall  F-measure  AUROC  AUPRC
# Focal Loss            0.836      0.653   0.656      0.654  0.845  0.677
# BCEWithLogitsLoss     0.828      0.683   0.510      0.584  0.828  0.653

# %%
df_3672 = pd.read_excel(xlsx_file,'PPI3672',index_col=0)
df_3672
# Out:
#                    Accuracy  Precision  Recall  F-measure  AUROC  AUPRC
# Focal Loss            0.807      0.576   0.663      0.616  0.826  0.602
# BCEWithLogitsLoss     0.813      0.606   0.581      0.594  0.820  0.596

# %%
df_2708 = pd.read_excel(xlsx_file,'PPI2708',index_col=0)
df_2708
# Out:
#                    Accuracy  Precision  Recall  F-measure  AUROC  AUPRC
# Focal Loss            0.806      0.704   0.614      0.656  0.806  0.700
# BCEWithLogitsLoss     0.791      0.708   0.522      0.601  0.784  0.682

# %% [markdown]
# ## PPI5093

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.render import make_snapshot
from snapshot_phantomjs import snapshot

# %%
# focal loss VS cross entropy loss
bar1 = (
    Bar()
    .add_xaxis(df_5093.columns.to_list())
    .add_yaxis('FL',df_5093.iloc[0,:].to_list(),color='#C52A20')
    .add_yaxis('BCE',df_5093.iloc[1,:].to_list(),color='#669BBB')
    .set_global_opts(xaxis_opts=opts.AxisOpts(name='metrics'))
    .set_global_opts(yaxis_opts=opts.AxisOpts(name='values'))
    .set_global_opts(legend_opts=opts.LegendOpts(pos_left='right',
                                                 orient='horizontal'))
    .set_global_opts(title_opts=opts.TitleOpts(pos_left='center',
                                               pos_top=20))
    .set_series_opts(label_opts=opts.LabelOpts(position='top'))
    #  ToolboxOpts:Toolbox Configurations
    .set_global_opts(toolbox_opts=opts.ToolboxOpts(is_show = True,
                                                     pos_top = 'bottom',
                                                     pos_left = 'right',
                     # 5 represents 5 times the resolution, the default is 1, the bigger the number, the clearer the saved picture is. 
                     feature={'saveAsImage':{'pixelRatio':5}}))

)
bar1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f9187586fe074f62b5f49f481cbdf0f6" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f9187586fe074f62b5f49f481cbdf0f6 = echarts.init(
#                     document.getElementById('f9187586fe074f62b5f49f481cbdf0f6'), 'white', {renderer: 'canvas'});
#                 var option_f9187586fe074f62b5f49f481cbdf0f6 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#C52A20",
#         "#669BBB",
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "FL",
#             "legendHoverLink": true,
#             "data": [
#                 0.836,
#                 0.653,
#                 0.656,
#                 0.654,
#                 0.845,
#                 0.677
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "BCE",
#             "legendHoverLink": true,
#             "data": [
#                 0.828,
#                 0.683,
#                 0.51,
#                 0.584,
#                 0.828,
#                 0.653
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "FL",
#                 "BCE"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10,
#             "left": "right",
#             "orient": "horizontal"
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "name": "metrics",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "Accuracy",
#                 "Precision",
#                 "Recall",
#                 "F-measure",
#                 "AUROC",
#                 "AUPRC"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "values",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "horizontal",
#         "itemSize": 15,
#         "itemGap": 10,
#         "left": "right",
#         "top": "bottom",
#         "feature": {
#             "saveAsImage": {
#                 "pixelRatio": 5
#             }
#         }
#     }
# };
#                 chart_f9187586fe074f62b5f49f481cbdf0f6.setOption(option_f9187586fe074f62b5f49f481cbdf0f6);
#         });
#     </script>

# %% [markdown]
# ### PPI3672

# %%
# focal loss VS cross entropy loss
bar2 = (
    Bar()
    .add_xaxis(df_3672.columns.to_list())
    .add_yaxis('FL',df_3672.iloc[0,:].to_list(),color='#C52A20')
    .add_yaxis('BCE',df_3672.iloc[1,:].to_list(),color='#669BBB')
    .set_global_opts(xaxis_opts=opts.AxisOpts(name='metrics'))
    .set_global_opts(yaxis_opts=opts.AxisOpts(name='values'))
    .set_global_opts(legend_opts=opts.LegendOpts(pos_left='right',
                                                 orient='horizontal'))
    .set_global_opts(title_opts=opts.TitleOpts(pos_left='center',
                                               pos_top=20))
    .set_series_opts(label_opts=opts.LabelOpts(position='top'))
    #  ToolboxOpts:Toolbox Configurations
    .set_global_opts(toolbox_opts=opts.ToolboxOpts(is_show = True,
                                                     pos_top = 'bottom',
                                                     pos_left = 'right',
                     # 5 represents 5 times the resolution, the default is 1, the bigger the number, the clearer the saved picture is. 
                     feature={'saveAsImage':{'pixelRatio':5}}))

)
bar2.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="627822763a5b41e9a6f34e5969d5ec07" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_627822763a5b41e9a6f34e5969d5ec07 = echarts.init(
#                     document.getElementById('627822763a5b41e9a6f34e5969d5ec07'), 'white', {renderer: 'canvas'});
#                 var option_627822763a5b41e9a6f34e5969d5ec07 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#C52A20",
#         "#669BBB",
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "FL",
#             "legendHoverLink": true,
#             "data": [
#                 0.807,
#                 0.576,
#                 0.663,
#                 0.616,
#                 0.826,
#                 0.602
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "BCE",
#             "legendHoverLink": true,
#             "data": [
#                 0.813,
#                 0.606,
#                 0.581,
#                 0.594,
#                 0.82,
#                 0.596
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "FL",
#                 "BCE"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10,
#             "left": "right",
#             "orient": "horizontal"
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "name": "metrics",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "Accuracy",
#                 "Precision",
#                 "Recall",
#                 "F-measure",
#                 "AUROC",
#                 "AUPRC"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "values",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "horizontal",
#         "itemSize": 15,
#         "itemGap": 10,
#         "left": "right",
#         "top": "bottom",
#         "feature": {
#             "saveAsImage": {
#                 "pixelRatio": 5
#             }
#         }
#     }
# };
#                 chart_627822763a5b41e9a6f34e5969d5ec07.setOption(option_627822763a5b41e9a6f34e5969d5ec07);
#         });
#     </script>

# %% [markdown]
# ### PPI2708

# %%
# focal loss VS cross entropy loss
bar3 = (
    Bar()
    .add_xaxis(df_2708.columns.to_list())
    .add_yaxis('FL',df_2708.iloc[0,:].to_list(),color='#C52A20')
    .add_yaxis('BCE',df_2708.iloc[1,:].to_list(),color='#669BBB')
    .set_global_opts(xaxis_opts=opts.AxisOpts(name='metrics'))
    .set_global_opts(yaxis_opts=opts.AxisOpts(name='values'))
    .set_global_opts(legend_opts=opts.LegendOpts(pos_left='right',
                                                 orient='horizontal'))
    .set_global_opts(title_opts=opts.TitleOpts(title='PPI2708 dataset',
                                               pos_left='center',
                                               pos_top=20))
    .set_series_opts(label_opts=opts.LabelOpts(position='top'))
    #  ToolboxOpts:Toolbox Configurations
    .set_global_opts(toolbox_opts=opts.ToolboxOpts(is_show = True,
                                                     pos_top = 'bottom',
                                                     pos_left = 'right',
                     # 5 represents 5 times the resolution, the default is 1, the bigger the number, the clearer the saved picture is. 
                     feature={'saveAsImage':{'pixelRatio':5}}))

)
bar3.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4fd56c221b074d14905a04749e97b6d7" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4fd56c221b074d14905a04749e97b6d7 = echarts.init(
#                     document.getElementById('4fd56c221b074d14905a04749e97b6d7'), 'white', {renderer: 'canvas'});
#                 var option_4fd56c221b074d14905a04749e97b6d7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#C52A20",
#         "#669BBB",
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "FL",
#             "legendHoverLink": true,
#             "data": [
#                 0.806,
#                 0.704,
#                 0.614,
#                 0.656,
#                 0.806,
#                 0.7
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "BCE",
#             "legendHoverLink": true,
#             "data": [
#                 0.791,
#                 0.708,
#                 0.522,
#                 0.601,
#                 0.784,
#                 0.682
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "FL",
#                 "BCE"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10,
#             "left": "right",
#             "orient": "horizontal"
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "name": "metrics",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "Accuracy",
#                 "Precision",
#                 "Recall",
#                 "F-measure",
#                 "AUROC",
#                 "AUPRC"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "values",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "horizontal",
#         "itemSize": 15,
#         "itemGap": 10,
#         "left": "right",
#         "top": "bottom",
#         "feature": {
#             "saveAsImage": {
#                 "pixelRatio": 5
#             }
#         }
#     }
# };
#                 chart_4fd56c221b074d14905a04749e97b6d7.setOption(option_4fd56c221b074d14905a04749e97b6d7);
#         });
#     </script>
