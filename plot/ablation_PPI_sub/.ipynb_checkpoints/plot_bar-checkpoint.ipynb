# %%
import pandas as pd
from pyecharts import options as opts
from pyecharts.charts import Bar

# %% [markdown]
# ## input

# %%
xlsx_file = pd.ExcelFile('ablation_result.xlsx')

# %%
df_5093 = pd.read_excel(xlsx_file,'PPI5093',index_col=0)
df_5093 = df_5093.iloc[:,0:4]
df_5093
# Out:
#                 Accuracy  Precision  Recall  F-measure
# EPViT(PPI+sub)     0.836      0.653   0.656      0.654
# only PPI           0.237      0.237   1.000      0.383
# only sub           0.819      0.611   0.652      0.631

# %%
df_3672 = pd.read_excel(xlsx_file,'PPI3672',index_col=0)
df_3672 = df_3672.iloc[:,0:4]
df_3672
# Out:
#                 Accuracy  Precision  Recall  F-measure
# EPViT(PPI+sub)     0.807      0.576   0.663      0.616
# only PPI           0.349      0.237   0.802      0.366
# only sub           0.781      0.527   0.634      0.575

# %%
df_2708 = pd.read_excel(xlsx_file,'PPI2708',index_col=0)
df_2708 = df_2708.iloc[:,0:4]
df_2708
# Out:
#                 Accuracy  Precision  Recall  F-measure
# EPViT(PPI+sub)     0.806      0.704   0.614      0.656
# only PPI           0.301      0.301   1.000      0.463
# only sub           0.778      0.637   0.614      0.625

# %% [markdown]
# ## PPI5093

# %%
bar1 = (
    Bar()
    .add_xaxis(df_5093.columns.to_list())
    .add_yaxis('EPViT(PPI+sub)',df_5093.iloc[0,:].to_list(),color='#C52A20')
    .add_yaxis('only PPI',df_5093.iloc[1,:].to_list(),color='#FFA500')
    .add_yaxis('only sub',df_5093.iloc[2,:].to_list(),color='#808080')

    .set_global_opts(xaxis_opts=opts.AxisOpts(name='metrics'))
    .set_global_opts(yaxis_opts=opts.AxisOpts(name='values'))
    .set_global_opts(legend_opts=opts.LegendOpts(pos_left='right',
                                                 orient='horizontal'))
    .set_global_opts(title_opts=opts.TitleOpts(pos_left='center',
                                               pos_top=20))
#     .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_series_opts(label_opts=opts.LabelOpts(position='top',
                                              font_size=10))
    #  ToolboxOpts:Toolbox Configurations
    .set_global_opts(toolbox_opts=opts.ToolboxOpts(is_show = True,
                                                     pos_top = 'bottom',
                                                     pos_left = 'right',
                     # 5 represents 5 times the resolution, the default is 1, the bigger the number, the clearer the saved picture is. 
                     feature={'saveAsImage':{'pixelRatio':5}}))

)

# %%
bar1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="dd9416e6708146d4918e0bee754bf948" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_dd9416e6708146d4918e0bee754bf948 = echarts.init(
#                     document.getElementById('dd9416e6708146d4918e0bee754bf948'), 'white', {renderer: 'canvas'});
#                 var option_dd9416e6708146d4918e0bee754bf948 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#C52A20",
#         "#FFA500",
#         "#808080",
# ...

# %% [markdown]
# ### PPI3672

# %%
bar2 = (
    Bar()
    .add_xaxis(df_3672.columns.to_list())
    .add_yaxis('EPViT(PPI+sub',df_3672.iloc[0,:].to_list(),color='#C52A20')
    .add_yaxis('only PPI',df_3672.iloc[1,:].to_list(),color='#FFA500')
    .add_yaxis('only sub',df_3672.iloc[2,:].to_list(),color='#808080')

    .set_global_opts(xaxis_opts=opts.AxisOpts(name='metrics'))
    .set_global_opts(yaxis_opts=opts.AxisOpts(name='values'))
    .set_global_opts(legend_opts=opts.LegendOpts(pos_left='right',
                                                 orient='horizontal'))
    .set_global_opts(title_opts=opts.TitleOpts(pos_left='center',
                                               pos_top=20))
    .set_series_opts(label_opts=opts.LabelOpts(position='top',
                                              font_size=10))
    .set_global_opts(toolbox_opts=opts.ToolboxOpts(is_show = True,
                                                 pos_top = 'bottom',
                                                 pos_left = 'right',
                 feature={'saveAsImage':{'pixelRatio':5}}))

)

# %%
bar2.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d5801a85777a42a68c1cad6524fea9ec" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d5801a85777a42a68c1cad6524fea9ec = echarts.init(
#                     document.getElementById('d5801a85777a42a68c1cad6524fea9ec'), 'white', {renderer: 'canvas'});
#                 var option_d5801a85777a42a68c1cad6524fea9ec = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#C52A20",
#         "#FFA500",
#         "#808080",
# ...

# %% [markdown]
# ### PPI2708

# %%
bar3 = (
    Bar()
    .add_xaxis(df_2708.columns.to_list())
    .add_yaxis('EPViT(PPI+sub)',df_2708.iloc[0,:].to_list(),color='#C52A20')
    .add_yaxis('only PPI',df_2708.iloc[1,:].to_list(),color='#FFA500')
    .add_yaxis('only sub',df_2708.iloc[2,:].to_list(),color='#808080')

    .set_global_opts(xaxis_opts=opts.AxisOpts(name='metrics'))
    .set_global_opts(yaxis_opts=opts.AxisOpts(name='values'))
    .set_global_opts(legend_opts=opts.LegendOpts(pos_left='right',
                                                 orient='horizontal'))
    .set_global_opts(title_opts=opts.TitleOpts(pos_left='center',
                                               pos_top=20))
    .set_series_opts(label_opts=opts.LabelOpts(position='top',
                                              font_size=10))
    .set_global_opts(toolbox_opts=opts.ToolboxOpts(is_show = True,
                                             pos_top = 'bottom',
                                             pos_left = 'right',
             feature={'saveAsImage':{'pixelRatio':5}}))

)

# %%
bar3.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f48f3fc931234dd88ae003081a81cf82" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f48f3fc931234dd88ae003081a81cf82 = echarts.init(
#                     document.getElementById('f48f3fc931234dd88ae003081a81cf82'), 'white', {renderer: 'canvas'});
#                 var option_f48f3fc931234dd88ae003081a81cf82 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#C52A20",
#         "#FFA500",
#         "#808080",
# ...
